# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ### Cleaning the IMDB Data
#
# Initially, I had planned to iterate through and scrape the individual pages for film and director.  To this end, I selected the unique IMDB ids for director and title from the urls present on the title search page.  I also separated out the three genre keywords, intending to use all three columns as part of the analysis. Ultimately, I used only the first of the three keywords, and I used the aggregate information for each director within the dataset for the film counts for each.
#
# Rather than cleaning and formatting each string or data type as it came through the for loops in the data scraping, I cleaned and formatted them here using the Pandas series.

# %%
imdb_df2 = pd.read_json('imdb_data2.json', lines=True)
# lines=True : read file as a json object per line

# %%
imdb_df2.head()
# Out:
#                                     title                        title_link  \
# 0                             Trancers II  /title/tt0103116/?ref_=adv_li_tt
# 1                                   Drive  /title/tt0116147/?ref_=adv_li_tt
# 2  Timerider: The Adventure of Lyle Swann  /title/tt0086443/?ref_=adv_li_tt
# 3                                  Thirst  /title/tt3955808/?ref_=adv_li_tt
# 4             I Married a Strange Person!  /title/tt0119346/?ref_=adv_li_tt
#
#   mpaa_rating          year  runtime  imdb_rating  metascore   votes  \
# 0           R        (1991)   88 min          5.4        NaN  1847.0
# 1           R        (1997)  100 min          6.8        NaN  5451.0
# 2          PG        (1982)   94 min          5.4        NaN  2005.0
# 3         NaN  (III) (2015)   87 min          4.4        NaN  1045.0
# 4           R        (1997)   75 min          7.0        NaN  1781.0
#
#    director_name                      director_link  \
# 0   Charles Band  /name/nm0023929/?ref_=adv_li_dr_0
# 1     Steve Wang  /name/nm0911036/?ref_=adv_li_dr_0
# 2   William Dear  /name/nm0213100/?ref_=adv_li_dr_0
# 3    Greg Kiefer  /name/nm2279788/?ref_=adv_li_dr_0
# 4  Bill Plympton  /name/nm0687739/?ref_=adv_li_dr_0
#
#                            imdb_genre_list
# 0     \nAction, Horror, Sci-Fi
# 1  \nAction, Adventure, Sci-Fi
# 2  \nAction, Adventure, Sci-Fi
# 3  \nAction, Adventure, Horror
# 4   \nAnimation, Comedy, Drama

# %% [markdown]
# #### Segmenting Out Unique IDs for Title and Director
#
# The second segment of the title url (`title_link`) is the unique `imdb_id` for the film, facilitating specific title searching on both IMDB and Box Office Mojo.  The unique link url for each director had a similar ID.

# %%
imdb_df2['imdb_id'] = (imdb_df2['title_link'].str.split("/", n=3, expand=True))[2]                               
imdb_df2['imdb_id']
# Out:
# 0       tt0103116
# 1       tt0116147
# 2       tt0086443
# 3       tt3955808
# 4       tt0119346
#           ...
# 1995    tt4235644
# 1996    tt0047930
# 1997    tt0102562
# 1998    tt3118442
# 1999    tt4920098
# Name: imdb_id, Length: 2000, dtype: object

# %%
imdb_df2['director_id'] = (imdb_df2['director_link'].str.split("/", n=3, expand=True))[2]                               
imdb_df2['director_id']
# Out:
# 0       nm0023929
# 1       nm0911036
# 2       nm0213100
# 3       nm2279788
# 4       nm0687739
#           ...
# 1995    nm2606944
# 1996    nm0954724
# 1997    nm0525475
# 1998    nm2204106
# 1999    nm4407169
# Name: director_id, Length: 2000, dtype: object

# %%
imdb_df2.head()
# Out:
#                                     title                        title_link  \
# 0                             Trancers II  /title/tt0103116/?ref_=adv_li_tt
# 1                                   Drive  /title/tt0116147/?ref_=adv_li_tt
# 2  Timerider: The Adventure of Lyle Swann  /title/tt0086443/?ref_=adv_li_tt
# 3                                  Thirst  /title/tt3955808/?ref_=adv_li_tt
# 4             I Married a Strange Person!  /title/tt0119346/?ref_=adv_li_tt
#
#   mpaa_rating          year  runtime  imdb_rating  metascore   votes  \
# 0           R        (1991)   88 min          5.4        NaN  1847.0
# 1           R        (1997)  100 min          6.8        NaN  5451.0
# 2          PG        (1982)   94 min          5.4        NaN  2005.0
# 3         NaN  (III) (2015)   87 min          4.4        NaN  1045.0
# 4           R        (1997)   75 min          7.0        NaN  1781.0
#
#    director_name                      director_link  \
# 0   Charles Band  /name/nm0023929/?ref_=adv_li_dr_0
# 1     Steve Wang  /name/nm0911036/?ref_=adv_li_dr_0
# 2   William Dear  /name/nm0213100/?ref_=adv_li_dr_0
# 3    Greg Kiefer  /name/nm2279788/?ref_=adv_li_dr_0
# 4  Bill Plympton  /name/nm0687739/?ref_=adv_li_dr_0
#
#                            imdb_genre_list    imdb_id director_id
# 0     \nAction, Horror, Sci-Fi              tt0103116   nm0023929
# 1  \nAction, Adventure, Sci-Fi              tt0116147   nm0911036
# 2  \nAction, Adventure, Sci-Fi              tt0086443   nm0213100
# 3  \nAction, Adventure, Horror              tt3955808   nm2279788
# 4   \nAnimation, Comedy, Drama              tt0119346   nm0687739

# %% [markdown]
# #### Splitting Up Genre Keywords Into Individual Features

# %%
imdb_df2[['genre_01', 'genre_02', 'genre_03']] = imdb_df2['imdb_genre_list'].str.split(", ", n=2, expand=True)

# %%
imdb_df2[['genre_01', 'genre_02', 'genre_03']].head()
# Out:
#       genre_01   genre_02            genre_03
# 0     \nAction     Horror  Sci-Fi
# 1     \nAction  Adventure  Sci-Fi
# 2     \nAction  Adventure  Sci-Fi
# 3     \nAction  Adventure  Horror
# 4  \nAnimation     Comedy   Drama

# %%
imdb_df2['genre_01'] = imdb_df2['genre_01'].str.strip("\n")

# %% [markdown]
# #### String Cleaning, Type Standardization, Dropping of Null Values

# %%
imdb_df2['runtime'] = imdb_df2['runtime'].str.strip(' min')
imdb_df2['runtime']= imdb_df2['runtime'].replace('', np.NaN)
imdb_df2['runtime'] = pd.to_numeric(imdb_df2['runtime'], errors='coerce')

# %%
imdb_df2.head()
# Out:
#                                     title                        title_link  \
# 0                             Trancers II  /title/tt0103116/?ref_=adv_li_tt
# 1                                   Drive  /title/tt0116147/?ref_=adv_li_tt
# 2  Timerider: The Adventure of Lyle Swann  /title/tt0086443/?ref_=adv_li_tt
# 3                                  Thirst  /title/tt3955808/?ref_=adv_li_tt
# 4             I Married a Strange Person!  /title/tt0119346/?ref_=adv_li_tt
#
#   mpaa_rating          year  runtime  imdb_rating  metascore   votes  \
# 0           R        (1991)     88.0          5.4        NaN  1847.0
# 1           R        (1997)    100.0          6.8        NaN  5451.0
# 2          PG        (1982)     94.0          5.4        NaN  2005.0
# 3         NaN  (III) (2015)     87.0          4.4        NaN  1045.0
# 4           R        (1997)     75.0          7.0        NaN  1781.0
#
#    director_name                      director_link  \
# 0   Charles Band  /name/nm0023929/?ref_=adv_li_dr_0
# 1     Steve Wang  /name/nm0911036/?ref_=adv_li_dr_0
# 2   William Dear  /name/nm0213100/?ref_=adv_li_dr_0
# 3    Greg Kiefer  /name/nm2279788/?ref_=adv_li_dr_0
# 4  Bill Plympton  /name/nm0687739/?ref_=adv_li_dr_0
#
#                            imdb_genre_list    imdb_id director_id   genre_01  \
# 0     \nAction, Horror, Sci-Fi              tt0103116   nm0023929     Action
# 1  \nAction, Adventure, Sci-Fi              tt0116147   nm0911036     Action
# 2  \nAction, Adventure, Sci-Fi              tt0086443   nm0213100     Action
# 3  \nAction, Adventure, Horror              tt3955808   nm2279788     Action
# 4   \nAnimation, Comedy, Drama              tt0119346   nm0687739  Animation
#
#     genre_02            genre_03
# 0     Horror  Sci-Fi
# 1  Adventure  Sci-Fi
# 2  Adventure  Sci-Fi
# 3  Adventure  Horror
# 4     Comedy   Drama

# %% [markdown]
# ####  Formatting Column Labels

# %%
imdb_df.columns
# Out:
# Index(['title', 'title_link', 'mpaa_rating', 'year', 'runtime', 'imdb_rating',
#        'metascore', 'votes', 'director_name', 'director_link',
#        'imdb_genre_list', 'imdb_id', 'director_id', 'genre_01', 'genre_02',
#        'genre_03'],
#       dtype='object')

# %%
imdb_df2 = imdb_df2[['title', 'imdb_id', 'title_link', 'year', 'runtime', 'mpaa_rating', 'director_name', 'director_id', 'director_link', 'genre_01', 'genre_02', 'genre_03','imdb_rating', 'votes', 'metascore']]

# %%
imdb_df2['runtime'].unique()
# Out:
# array([ 88., 100.,  94.,  87.,  75.,  95., 179.,  86.,  90.,  83., 117.,
#         84., 216.,  nan,  85., 114.,  89., 113., 126., 111., 106.,  71.,
#         97.,  92., 127.,  74.,  99., 102.,  73.,  98.,  45., 174.,  72.,
#        110., 151.,  78., 101., 115., 116.,  62.,  81.,  96.,  91., 103.,
#        125., 129.,  66.,  93.,  49.,  80.,  82.,  77.,  76.,  79.,  67.,
#        105., 107., 141., 164., 142.,  60., 118.,  69., 354.,  65.,  63.,
#         54.,  68., 108., 149., 104., 120., 135.,  59., 140., 119.,  70.,
#         53., 134.,  58.,  61., 136.,  47., 112.,  64., 237.,  55., 154.,
#        124., 138., 167., 121.,  51., 123.,  50., 299.,  57., 220.,  46.,
#        180., 252.,  52.,  48., 109., 258., 160., 152., 130., 132., 165.,
#        133., 137., 128., 122., 146., 173., 226., 265., 195.])

# %%
imdb_df2['votes']= imdb_df2['votes'].replace('', np.NaN)
imdb_df2['votes'] = pd.to_numeric(imdb_df2['votes'], errors='coerce')

# %%
imdb_df2['votes'].unique()
# Out:
# array([1847., 5451., 2005., ...,  592., 1051., 1651.])

# %%
imdb_df2.head()
# Out:
#                                     title    imdb_id  \
# 0                             Trancers II  tt0103116
# 1                                   Drive  tt0116147
# 2  Timerider: The Adventure of Lyle Swann  tt0086443
# 3                                  Thirst  tt3955808
# 4             I Married a Strange Person!  tt0119346
#
#                          title_link          year  runtime mpaa_rating  \
# 0  /title/tt0103116/?ref_=adv_li_tt        (1991)     88.0           R
# 1  /title/tt0116147/?ref_=adv_li_tt        (1997)    100.0           R
# 2  /title/tt0086443/?ref_=adv_li_tt        (1982)     94.0          PG
# 3  /title/tt3955808/?ref_=adv_li_tt  (III) (2015)     87.0         NaN
# 4  /title/tt0119346/?ref_=adv_li_tt        (1997)     75.0           R
#
#    director_name director_id                      director_link   genre_01  \
# 0   Charles Band   nm0023929  /name/nm0023929/?ref_=adv_li_dr_0     Action
# 1     Steve Wang   nm0911036  /name/nm0911036/?ref_=adv_li_dr_0     Action
# 2   William Dear   nm0213100  /name/nm0213100/?ref_=adv_li_dr_0     Action
# 3    Greg Kiefer   nm2279788  /name/nm2279788/?ref_=adv_li_dr_0     Action
# 4  Bill Plympton   nm0687739  /name/nm0687739/?ref_=adv_li_dr_0  Animation
#
#     genre_02            genre_03  imdb_rating   votes  metascore
# 0     Horror  Sci-Fi                      5.4  1847.0        NaN
# 1  Adventure  Sci-Fi                      6.8  5451.0        NaN
# 2  Adventure  Sci-Fi                      5.4  2005.0        NaN
# 3  Adventure  Horror                      4.4  1045.0        NaN
# 4     Comedy   Drama                      7.0  1781.0        NaN

# %%
imdb_df2['year'] = imdb_df2['year'].str.strip('[)XIV( ]')

# %%
imdb_df2['year'].unique()
# Out:
# array(['1991', '1997', '1982', '2015', '2005', '1987', '1983', '2013',
#        '1962', '2018', '1979', '1966', '1941', '2017', '2021', '2019',
#        '1965', '1971', '2020', '', '1956', '2016', '1968', '1999', '1994',
#        '1993', '1992', '1939', '1977', '1954', '1972', '1967', '1958',
#        '2002', '1975', '1998', '1985', '2010', '1984', '1944', '1974',
#        '1981', '1995', '2003', '2012', '1986', '1957', '2009', '2007',
#        '2006', '1940', '1953', '1996', '1970', '1988', '1943', '1969',
#        '1936', '2014', '1932', '1990', '1964', '1955', '1942', '2008',
#        '2001', '1989', '1973', '2011', '1961', '2000', '2004', '1959',
#        '1963', '1960', '1980', '1976', '1920', '1945', '1951', '1950',
#        '1931', '1935', '1952', '1924', '1978', '1938', '1946', '1916',
#        '2022', '1928', '1933', '1947', '2025', '1925', '1948'],
#       dtype=object)

# %%
imdb_df2['year']= imdb_df2['year'].replace('', np.NaN)

# %%
imdb_df2['year'].unique()
# Out:
# array(['1991', '1997', '1982', '2015', '2005', '1987', '1983', '2013',
#        '1962', '2018', '1979', '1966', '1941', '2017', '2021', '2019',
#        '1965', '1971', '2020', nan, '1956', '2016', '1968', '1999',
#        '1994', '1993', '1992', '1939', '1977', '1954', '1972', '1967',
#        '1958', '2002', '1975', '1998', '1985', '2010', '1984', '1944',
#        '1974', '1981', '1995', '2003', '2012', '1986', '1957', '2009',
#        '2007', '2006', '1940', '1953', '1996', '1970', '1988', '1943',
#        '1969', '1936', '2014', '1932', '1990', '1964', '1955', '1942',
#        '2008', '2001', '1989', '1973', '2011', '1961', '2000', '2004',
#        '1959', '1963', '1960', '1980', '1976', '1920', '1945', '1951',
#        '1950', '1931', '1935', '1952', '1924', '1978', '1938', '1946',
#        '1916', '2022', '1928', '1933', '1947', '2025', '1925', '1948'],
#       dtype=object)

# %%
imdb_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          2000 non-null   object
#  1   imdb_id        2000 non-null   object
#  2   title_link     2000 non-null   object
#  3   year           1844 non-null   object
#  4   runtime        1808 non-null   float64
#  5   mpaa_rating    2000 non-null   object
#  6   director_name  2000 non-null   object
#  7   director_id    1732 non-null   object
#  8   director_link  2000 non-null   object
#  9   genre_01       2000 non-null   object
#  10  genre_02       1811 non-null   object
#  11  genre_03       1290 non-null   object
#  12  imdb_rating    1800 non-null   float64
#  13  votes          1800 non-null   float64
#  14  metascore      83 non-null     float64
# dtypes: float64(4), object(11)
# memory usage: 234.5+ KB

# %%
imdb_df2.sample(10, random_state=42)
# Out:
#                                                  title    imdb_id  \
# 1860                                     Chronesthesia  tt5729870
# 353                                         The Sender  tt0084658
# 1333                                            Medusa  tt3237826
# 905                                   Invasion, U.S.A.  tt0044750
# 1289                                     Watch the Sky  tt5083366
# 1273                                       Future Cops  tt0106545
# 938                            Assignment: Outer Space  tt0054330
# 1731                                          Doomsday  tt2805976
# 65              Quantum Quest: A Cassini Space Odyssey  tt0312305
# 1323  Alien Showdown: The Day the Old West Stood Still  tt2349142
#
#                             title_link  year  runtime mpaa_rating  \
# 1860  /title/tt5729870/?ref_=adv_li_tt  2016     93.0         NaN
# 353   /title/tt0084658/?ref_=adv_li_tt  1982     91.0           R
# 1333  /title/tt3237826/?ref_=adv_li_tt  2015    109.0         NaN
# 905   /title/tt0044750/?ref_=adv_li_tt  1952     73.0    Approved
# 1289  /title/tt5083366/?ref_=adv_li_tt  2017     87.0         NaN
# 1273  /title/tt0106545/?ref_=adv_li_tt  1993     95.0   Not Rated
# 938   /title/tt0054330/?ref_=adv_li_tt  1960     73.0     Unrated
# 1731  /title/tt2805976/?ref_=adv_li_tt  2015     95.0   Not Rated
# 65    /title/tt0312305/?ref_=adv_li_tt  2010     45.0         NaN
# 1323  /title/tt2349142/?ref_=adv_li_tt  2018     80.0         NaN
#
#            director_name director_id                      director_link  \
# 1860      Hayden J. Weal   nm3289442  /name/nm3289442/?ref_=adv_li_dr_0
# 353      Roger Christian   nm0002337  /name/nm0002337/?ref_=adv_li_dr_0
# 1333         Jorge Ameer   nm0024521  /name/nm0024521/?ref_=adv_li_dr_0
# 905      Alfred E. Green   nm0337586  /name/nm0337586/?ref_=adv_li_dr_0
# 1289   Alexander Murillo   nm7167050  /name/nm7167050/?ref_=adv_li_dr_0
# 1273           Jing Wong   nm0939147  /name/nm0939147/?ref_=adv_li_dr_0
# 938   Antonio Margheriti   nm0546672  /name/nm0546672/?ref_=adv_li_dr_0
# 1731        Neil Johnson   nm1484928  /name/nm1484928/?ref_=adv_li_dr_0
# 65                   NaN        None                                NaN
# 1323          Rene Perez   nm3163561  /name/nm3163561/?ref_=adv_li_dr_0
#
#                 genre_01            genre_02              genre_03  \
# 1860              Comedy               Drama   Romance
# 353                Drama              Horror    Sci-Fi
# 1333              Horror              Sci-Fi  Thriller
# 905                Drama              Sci-Fi       War
# 1289               Drama  Sci-Fi                              None
# 1273              Action              Comedy    Sci-Fi
# 938   Sci-Fi                            None                  None
# 1731              Action  Sci-Fi                              None
# 65             Animation           Adventure    Sci-Fi
# 1323              Action           Adventure   Fantasy
#
#       imdb_rating   votes  metascore
# 1860          6.4   407.0        NaN
# 353           6.0  1692.0        NaN
# 1333          5.1   125.0        NaN
# 905           3.2  1258.0        NaN
# 1289          3.6   171.0        NaN
# 1273          6.0  1063.0        NaN
# 938           3.6   798.0        NaN
# 1731          3.5   200.0        NaN
# 65            5.1   319.0        NaN
# 1323          2.0   354.0        NaN

# %%
imdb_df2.describe()
# Out:
#            runtime  imdb_rating         votes  metascore
# count  1808.000000   1800.00000   1800.000000  83.000000
# mean     91.853982      4.99500   1547.030000  50.253012
# std      20.237295      1.46109   2006.358975  15.902787
# min      45.000000      1.10000      5.000000   8.000000
# 25%      83.000000      3.90000    392.000000  40.000000
# 50%      90.000000      5.10000    903.000000  49.000000
# 75%      97.000000      6.10000   1917.750000  63.000000
# max     354.000000      9.50000  24911.000000  84.000000

# %%
imdb_df2['year'].value_counts()
# Out:
# 2017    106
# 2018     98
# 2016     94
# 2019     78
# 2015     70
#        ...
# 1931      1
# 2025      1
# 1925      1
# 1945      1
# 1928      1
# Name: year, Length: 95, dtype: int64

# %% [markdown]
# #### Dropping Less Common MPAA Ratings Values

# %%
imdb_df2['mpaa_rating'].value_counts()
# let's drop some of these ratings, esp TV and X
# Out:
# NaN          722
# Not Rated    358
# R            338
# Approved     109
# PG           108
# Unrated       84
# PG-13         81
# TV-14         49
# TV-MA         43
# G             39
# Passed        29
# TV-PG         19
# GP             7
# X              4
# TV-Y7          3
# TV-Y7-FV       2
# M              2
# TV-G           2
# TV-Y           1
# Name: mpaa_rating, dtype: int64

# %%
imdb_df2['mpaa_rating'].unique()
# Out:
# array(['R', 'PG', 'NaN', 'PG-13', 'Not Rated', 'TV-MA', 'Passed',
#        'Approved', 'G', 'TV-PG', 'Unrated', 'TV-14', 'X', 'GP', 'M',
#        'TV-G', 'TV-Y7', 'TV-Y7-FV', 'TV-Y'], dtype=object)

# %%
imdb_df2['genre_01'].value_counts()
# Out:
# Action                561
# Horror                301
# Comedy                221
# Drama                 202
# Sci-Fi                189
# Animation             169
# Adventure             143
# Sci-Fi                 79
# Fantasy                32
# Crime                  32
# Mystery                28
# Family                 13
# Documentary            12
# Romance                 9
# Musical                 3
# Music                   3
# Biography               2
# History                 1
# Name: genre_01, dtype: int64

# %%
imdb_df2['genre_02'].value_counts()
# Out:
# Sci-Fi                   445
# Adventure                265
# Sci-Fi                   221
# Horror                   209
# Drama                    127
# Action                    98
# Comedy                    97
# Fantasy                   79
# Mystery                   72
# Thriller                  56
# Romance                   38
# Family                    35
# Crime                     29
# Horror                    11
# History                    5
# Musical                    5
# Music                      3
# Biography                  3
# Comedy                     2
# Drama                      2
# Action                     2
# Thriller                   2
# Adventure                  1
# Music                      1
# Western                    1
# Adult                      1
# Animation                  1
# Name: genre_02, dtype: int64

# %%
imdb_df2['genre_03'].value_counts()
# Out:
# Sci-Fi                   547
# Thriller                 209
# Comedy                    88
# Fantasy                   81
# Horror                    77
# Drama                     66
# Adventure                 56
# Mystery                   46
# Family                    39
# Romance                   37
# Crime                     18
# Musical                    9
# Music                      5
# War                        4
# History                    4
# Sport                      2
# Western                    1
# Action                     1
# Name: genre_03, dtype: int64

# %%
imdb_df2['genre_02']= imdb_df2['genre_02'].str.strip()

# %%
imdb_df2['genre_02'].value_counts()
# Out:
# Sci-Fi       666
# Adventure    266
# Horror       220
# Drama        129
# Action       100
# Comedy        99
# Fantasy       79
# Mystery       72
# Thriller      58
# Romance       38
# Family        35
# Crime         29
# History        5
# Musical        5
# Music          4
# Biography      3
# Adult          1
# Animation      1
# Western        1
# Name: genre_02, dtype: int64

# %%
imdb_df2['genre_03']= imdb_df2['genre_03'].str.strip()

# %%
imdb_df2['genre_03'].value_counts()
# Out:
# Sci-Fi       547
# Thriller     209
# Comedy        88
# Fantasy       81
# Horror        77
# Drama         66
# Adventure     56
# Mystery       46
# Family        39
# Romance       37
# Crime         18
# Musical        9
# Music          5
# History        4
# War            4
# Sport          2
# Action         1
# Western        1
# Name: genre_03, dtype: int64

# %%
imdb_df2['genre_01']= imdb_df2['genre_01'].str.strip()

# %%
imdb_df2['genre_01'].value_counts()
# Out:
# Action         561
# Horror         301
# Sci-Fi         268
# Comedy         221
# Drama          202
# Animation      169
# Adventure      143
# Fantasy         32
# Crime           32
# Mystery         28
# Family          13
# Documentary     12
# Romance          9
# Musical          3
# Music            3
# Biography        2
# History          1
# Name: genre_01, dtype: int64

# %%
imdb_df2.columns
# Out:
# Index(['title', 'imdb_id', 'title_link', 'year', 'runtime', 'mpaa_rating',
#        'director_name', 'director_id', 'director_link', 'genre_01', 'genre_02',
#        'genre_03', 'imdb_rating', 'votes', 'metascore'],
#       dtype='object')

# %%
imdb_lookup_df3 = imdb_df2_ms[['title', 'imdb_id','title_link', 'director_name', 'director_id', 'director_link']]

# %% [markdown]
# ####  Creating A Title String for URL Searching Rotten Tomatoes

# %%
imdb_lookup_df3['title_cc'] = imdb_df2_ms['title'].str.lower()
# Out:
# <ipython-input-178-553b52578699>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_lookup_df3['title_cc'] = imdb_df2_ms['title'].str.lower()

# %%
imdb_lookup_df3['title_cc'].head()
# Out:
# 8                       beneath
# 19      the million dollar duck
# 25        cities of last things
# 37                   lazer team
# 44    the powerpuff girls movie
# Name: title_cc, dtype: object

# %%
imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace('&','and',regex=False)
imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace('\\','_',regex=True)
imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace('episode\s([ivx]*)\s-\s','',regex=True)
imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace("\s",'_',regex=True)
imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace("\W",'',regex=True)
imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace('_+','_',regex=True)
# Out:
# <ipython-input-180-1310b7c90393>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace('&','and',regex=False)
# <ipython-input-180-1310b7c90393>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace('\\','_',regex=True)
# <ipython-input-180-1310b7c90393>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace('episode\s([ivx]*)\s-\s','',regex=True)
# <ipython-input-180-1310b7c90393>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace("\s",'_',regex=True)
# <ipython-input-180-1310b7c90393>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace("\W",'',regex=True)
# <ipython-input-180-1310b7c90393>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_lookup_df3['title_cc'] = imdb_lookup_df3['title_cc'].str.replace('_+','_',regex=True)

# %%
print(imdb_lookup_df3.shape)
imdb_lookup_df3.head()
# Out:
# (83, 7)
#                         title    imdb_id                        title_link  \
# 8                     Beneath  tt2325518  /title/tt2325518/?ref_=adv_li_tt
# 19    The Million Dollar Duck  tt0066728  /title/tt0066728/?ref_=adv_li_tt
# 25      Cities of Last Things  tt4397342  /title/tt4397342/?ref_=adv_li_tt
# 37                 Lazer Team  tt3864024  /title/tt3864024/?ref_=adv_li_tt
# 44  The Powerpuff Girls Movie  tt0289408  /title/tt0289408/?ref_=adv_li_tt
#
#        director_name director_id                      director_link  \
# 8    Larry Fessenden   nm0275244  /name/nm0275244/?ref_=adv_li_dr_0
# 19  Vincent McEveety   nm0568546  /name/nm0568546/?ref_=adv_li_dr_0
# 25        Wi Ding Ho   nm0387399  /name/nm0387399/?ref_=adv_li_dr_0
# 37       Matt Hullum   nm0401502  /name/nm0401502/?ref_=adv_li_dr_0
# 44   Craig McCracken   nm0566833  /name/nm0566833/?ref_=adv_li_dr_0
#
#                      title_cc
# 8                     beneath
# 19    the_million_dollar_duck
# 25      cities_of_last_things
# 37                 lazer_team
# 44  the_powerpuff_girls_movie

# %%
imdb_lookup_df2.shape
# Out:
# (2000, 7)

# %%
imdb_df2['director_name']= imdb_df2['director_name'].replace('NaN', np.NaN)

# %%
imdb_df2['director_id']= imdb_df2['director_id'].replace('NaN', np.NaN)

# %%
imdb_df2['director_id']= imdb_df2['director_id'].replace('None', np.NaN)

# %%
imdb_df2[imdb_df2.director_id.isna()]
# Out:
#                                                   title     imdb_id  \
# 14                         Adventures of Captain Marvel   tt0033317
# 23            Eiga Doraemon: Nobita no getsumen tansaki   tt9735672
# 24                                        The Last Days   tt1935914
# 26                                              Robodog   tt3501062
# 32                                            Carnosaur   tt0106521
# ...                                                 ...         ...
# 1931                                 Gamera vs. Barugon   tt0060446
# 1948                                             Axanar   tt3302086
# 1971                   GoBots: Battle of the Rock Lords   tt0091123
# 1981                                      Kekkai Sensen  tt10436054
# 1992  Star Worlds Episode XXXIVE=MC2: The Force Awak...   tt6520712
#
#                              title_link  year  runtime mpaa_rating  \
# 14     /title/tt0033317/?ref_=adv_li_tt  1941    216.0      Passed
# 23     /title/tt9735672/?ref_=adv_li_tt  2019    111.0         NaN
# 24     /title/tt1935914/?ref_=adv_li_tt  2013    100.0     Unrated
# 26     /title/tt3501062/?ref_=adv_li_tt   NaN      NaN         NaN
# 32     /title/tt0106521/?ref_=adv_li_tt  1993     83.0           R
# ...                                 ...   ...      ...         ...
# 1931   /title/tt0060446/?ref_=adv_li_tt  1966    106.0   Not Rated
# 1948   /title/tt3302086/?ref_=adv_li_tt   NaN      NaN         NaN
# 1971   /title/tt0091123/?ref_=adv_li_tt  1986     75.0           G
# 1981  /title/tt10436054/?ref_=adv_li_tt  2019      NaN         NaN
# 1992   /title/tt6520712/?ref_=adv_li_tt   NaN      NaN         NaN
#
#      director_name director_id director_link   genre_01   genre_02   genre_03  \
# 14             NaN        None           NaN     Action  Adventure    Fantasy
# 23             NaN        None           NaN  Animation     Action  Adventure
# 24             NaN        None           NaN     Horror     Sci-Fi   Thriller
# 26             NaN        None           NaN  Animation  Adventure     Comedy
# 32             NaN        None           NaN     Horror     Sci-Fi       None
# ...            ...         ...           ...        ...        ...        ...
# 1931           NaN        None           NaN     Action  Adventure    Fantasy
# 1948           NaN        None           NaN     Action  Adventure     Sci-Fi
# 1971           NaN        None           NaN  Animation     Action  Adventure
# 1981           NaN        None           NaN     Action  Adventure    Fantasy
# 1992           NaN        None           NaN     Comedy     Sci-Fi       None
#
#       imdb_rating   votes  metascore
# 14            7.2  1112.0        NaN
# 23            6.6   459.0        NaN
# 24            6.1  7942.0        NaN
# 26            NaN     NaN        NaN
# 32            3.6  3664.0        NaN
# ...           ...     ...        ...
# 1931          5.0  2030.0        NaN
# 1948          NaN     NaN        NaN
# 1971          5.8   463.0        NaN
# 1981          6.6     5.0        NaN
# 1992          NaN     NaN        NaN
#
# [268 rows x 15 columns]

# %%
imdb_df2['director_link']= imdb_df2['director_link'].replace('NaN', np.NaN)

# %%
imdb_df2['director_link']= imdb_df2['director_link'].replace('None', np.NaN)

# %%
imdb_df[imdb_df.director_link.isna()]
# Out:
#                                                   title     imdb_id  \
# 3                                     Avengers: Endgame   tt4154796
# 10                               Avengers: Infinity War   tt4154756
# 20                                           The Matrix   tt0133093
# 35                                       Captain Marvel   tt4154664
# 48                    Spider-Man: Into the Spider-Verse   tt4633694
# ...                                                 ...         ...
# 1969                                  The Shadow Effect   tt5044656
# 1975           The War of the Worlds: The Musical Drama  tt12106008
# 1980                               Godzilla vs. Megalon   tt0070122
# 1991  Aqua Teen Hunger Force Colon Movie Film for Th...   tt0455326
# 1996                                    Captain America   tt0036697
#
#                              title_link  year  runtime mpaa_rating  \
# 3      /title/tt4154796/?ref_=adv_li_tt  2019    181.0       PG-13
# 10     /title/tt4154756/?ref_=adv_li_tt  2018    149.0       PG-13
# 20     /title/tt0133093/?ref_=adv_li_tt  1999    136.0           R
# 35     /title/tt4154664/?ref_=adv_li_tt  2019    123.0       PG-13
# 48     /title/tt4633694/?ref_=adv_li_tt  2018    117.0          PG
# ...                                 ...   ...      ...         ...
# 1969   /title/tt5044656/?ref_=adv_li_tt  2017     93.0   Not Rated
# 1975  /title/tt12106008/?ref_=adv_li_tt  2018      NaN         NaN
# 1980   /title/tt0070122/?ref_=adv_li_tt  1973     78.0         NaN
# 1991   /title/tt0455326/?ref_=adv_li_tt  2007     86.0           R
# 1996   /title/tt0036697/?ref_=adv_li_tt  1944    244.0    Approved
#
#      director_name director_id director_link   genre_01   genre_02   genre_03  \
# 3              NaN        None           NaN     Action  Adventure      Drama
# 10             NaN        None           NaN     Action  Adventure     Sci-Fi
# 20             NaN        None           NaN     Action     Sci-Fi       None
# 35             NaN        None           NaN     Action  Adventure     Sci-Fi
# 48             NaN        None           NaN  Animation     Action  Adventure
# ...            ...         ...           ...        ...        ...        ...
# 1969           NaN        None           NaN     Action    Mystery     Sci-Fi
# 1975           NaN        None           NaN  Adventure    Musical     Sci-Fi
# 1980           NaN        None           NaN     Action  Adventure     Family
# 1991           NaN        None           NaN  Animation     Action  Adventure
# 1996           NaN        None           NaN     Action  Adventure     Sci-Fi
#
#       imdb_rating      votes  metascore
# 3             8.4   802218.0       78.0
# 10            8.4   829607.0       68.0
# 20            8.7  1671469.0       73.0
# 35            6.9   438384.0       64.0
# 48            8.4   371835.0       87.0
# ...           ...        ...        ...
# 1969          4.2     1610.0        NaN
# 1975          7.1       12.0        NaN
# 1980          4.8     5049.0        NaN
# 1991          6.7    13323.0       54.0
# 1996          5.5      813.0        NaN
#
# [229 rows x 15 columns]

# %%
imdb_df2 = imdb_df2.replace('NaN', np.NaN)

# %%
imdb_df2 = imdb_df2.replace('None', np.NaN)

# %%
imdb_df2.isna().sum()
# Out:
# title               0
# imdb_id             0
# title_link          0
# year              156
# runtime           192
# mpaa_rating       722
# director_name     268
# director_id       268
# director_link     268
# genre_01            0
# genre_02          189
# genre_03          710
# imdb_rating       200
# votes             200
# metascore        1917
# dtype: int64

# %%
imdb_df2_ms = imdb_df2[imdb_df2['metascore'].notna()]

# %%
imdb_df2_ms.shape
# Out:
# (83, 15)

# %%
imdb_df2_ms.describe()
# Out:
#           runtime  imdb_rating         votes  metascore
# count   83.000000    83.000000     83.000000  83.000000
# mean    94.096386     5.697590   3423.650602  50.253012
# std     12.405363     0.947265   3221.284123  15.902787
# min     71.000000     3.200000     37.000000   8.000000
# 25%     86.000000     5.200000   1348.000000  40.000000
# 50%     91.000000     5.700000   2478.000000  49.000000
# 75%     99.500000     6.400000   3900.000000  63.000000
# max    129.000000     7.300000  17644.000000  84.000000

# %%
imdb_df2_ms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83 entries, 8 to 1768
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          83 non-null     object
#  1   imdb_id        83 non-null     object
#  2   title_link     83 non-null     object
#  3   year           83 non-null     object
#  4   runtime        83 non-null     float64
#  5   mpaa_rating    73 non-null     object
#  6   director_name  73 non-null     object
#  7   director_id    73 non-null     object
#  8   director_link  73 non-null     object
#  9   genre_01       83 non-null     object
#  10  genre_02       80 non-null     object
#  11  genre_03       69 non-null     object
#  12  imdb_rating    83 non-null     float64
#  13  votes          83 non-null     float64
#  14  metascore      83 non-null     float64
# dtypes: float64(4), object(11)
# memory usage: 10.4+ KB

# %%
imdb_df2_ms.head()
# Out:
#                         title    imdb_id                        title_link  \
# 8                     Beneath  tt2325518  /title/tt2325518/?ref_=adv_li_tt
# 19    The Million Dollar Duck  tt0066728  /title/tt0066728/?ref_=adv_li_tt
# 25      Cities of Last Things  tt4397342  /title/tt4397342/?ref_=adv_li_tt
# 37                 Lazer Team  tt3864024  /title/tt3864024/?ref_=adv_li_tt
# 44  The Powerpuff Girls Movie  tt0289408  /title/tt0289408/?ref_=adv_li_tt
#
#     year  runtime mpaa_rating     director_name director_id  \
# 8   2013     90.0   Not Rated   Larry Fessenden   nm0275244
# 19  1971     89.0           G  Vincent McEveety   nm0568546
# 25  2018    106.0       TV-MA        Wi Ding Ho   nm0387399
# 37  2015    102.0       PG-13       Matt Hullum   nm0401502
# 44  2002     73.0          PG   Craig McCracken   nm0566833
#
#                         director_link   genre_01 genre_02   genre_03  \
# 8   /name/nm0275244/?ref_=adv_li_dr_0     Horror   Sci-Fi   Thriller
# 19  /name/nm0568546/?ref_=adv_li_dr_0     Comedy   Family     Sci-Fi
# 25  /name/nm0387399/?ref_=adv_li_dr_0      Crime    Drama     Sci-Fi
# 37  /name/nm0401502/?ref_=adv_li_dr_0     Action   Comedy     Sci-Fi
# 44  /name/nm0566833/?ref_=adv_li_dr_0  Animation   Action  Adventure
#
#     imdb_rating   votes  metascore
# 8           3.7  2981.0       40.0
# 19          5.9  2021.0       45.0
# 25          6.2  1227.0       66.0
# 37          5.6  9128.0       42.0
# 44          6.6  9200.0       65.0

# %%
imdb_df2_ms.to_json('imdb_data_cleaned_2.json', orient='records', lines=True)

# %%
imdb_lookup_df3.to_json('imdb_lookup_df3.json', orient='records', lines=True)
