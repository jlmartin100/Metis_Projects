# %%
import numpy as np
import pandas as pd
import json

# %% [markdown]
# ## Merging Data Scraped From Multiple Sources Over Multiple Iterations
#
# With two rounds of data each scraped from IMDB, Rotten Tomatoes, Box Office Mojo, and The Numbers, merging the dataframes required some attention and care.
#
#
# The dataframes were joined on the lowercased underscored title string. However, due to issues with multiple movies sharing titles, or remakes of the same movie over a forty year period, it was also necessary to carefully weed out duplicate records, and to ensure that accurate release dates and budget information were appended to the correct film records.
#
# At this point, I also did some string cleaning and typecasting for data standardization.

# %%
imdb_df1 = pd.read_json('imdb_data_cleaned.json', lines=True)
imdb_df2 = pd.read_json('imdb_data_cleaned_2.json', lines=True)

# %%
imdb_df1.head()
# Out:
#                title     imdb_id                         title_link    year  \
# 0              Tenet   tt6723592   /title/tt6723592/?ref_=adv_li_tt  2020.0
# 1   The Midnight Sky  tt10539608  /title/tt10539608/?ref_=adv_li_tt  2020.0
# 2       Wonder Woman   tt0451279   /title/tt0451279/?ref_=adv_li_tt  2017.0
# 3  Avengers: Endgame   tt4154796   /title/tt4154796/?ref_=adv_li_tt  2019.0
# 4   Outside the Wire  tt10451914  /title/tt10451914/?ref_=adv_li_tt  2021.0
#
#    runtime mpaa_rating      director_name director_id  \
# 0    150.0       PG-13  Christopher Nolan   nm0634240
# 1    118.0       PG-13     George Clooney   nm0000123
# 2    141.0       PG-13      Patty Jenkins   nm0420941
# 3    181.0       PG-13               None        None
# 4    114.0           R    Mikael Håfström   nm0405632
#
#                        director_link genre_01   genre_02  genre_03  \
# 0  /name/nm0634240/?ref_=adv_li_dr_0   Action     Sci-Fi  Thriller
# 1  /name/nm0000123/?ref_=adv_li_dr_0    Drama    Fantasy    Sci-Fi
# 2  /name/nm0420941/?ref_=adv_li_dr_0   Action  Adventure   Fantasy
# 3                               None   Action  Adventure     Drama
# 4  /name/nm0405632/?ref_=adv_li_dr_0   Action  Adventure   Fantasy
#
#    imdb_rating     votes  metascore
# 0          7.5  268688.0       69.0
# 1          5.6   58011.0       58.0
# 2          7.4  564054.0       76.0
# 3          8.4  802218.0       78.0
# 4          5.4    9333.0       47.0

# %%
imdb_df2.head()
# Out:
#                        title    imdb_id                        title_link  \
# 0                    Beneath  tt2325518  /title/tt2325518/?ref_=adv_li_tt
# 1    The Million Dollar Duck  tt0066728  /title/tt0066728/?ref_=adv_li_tt
# 2      Cities of Last Things  tt4397342  /title/tt4397342/?ref_=adv_li_tt
# 3                 Lazer Team  tt3864024  /title/tt3864024/?ref_=adv_li_tt
# 4  The Powerpuff Girls Movie  tt0289408  /title/tt0289408/?ref_=adv_li_tt
#
#    year  runtime mpaa_rating     director_name director_id  \
# 0  2013       90   Not Rated   Larry Fessenden   nm0275244
# 1  1971       89           G  Vincent McEveety   nm0568546
# 2  2018      106       TV-MA        Wi Ding Ho   nm0387399
# 3  2015      102       PG-13       Matt Hullum   nm0401502
# 4  2002       73          PG   Craig McCracken   nm0566833
#
#                        director_link   genre_01 genre_02   genre_03  \
# 0  /name/nm0275244/?ref_=adv_li_dr_0     Horror   Sci-Fi   Thriller
# 1  /name/nm0568546/?ref_=adv_li_dr_0     Comedy   Family     Sci-Fi
# 2  /name/nm0387399/?ref_=adv_li_dr_0      Crime    Drama     Sci-Fi
# 3  /name/nm0401502/?ref_=adv_li_dr_0     Action   Comedy     Sci-Fi
# 4  /name/nm0566833/?ref_=adv_li_dr_0  Animation   Action  Adventure
#
#    imdb_rating  votes  metascore
# 0          3.7   2981         40
# 1          5.9   2021         45
# 2          6.2   1227         66
# 3          5.6   9128         42
# 4          6.6   9200         65

# %%
imdb_df1.shape
# Out:
# (2000, 15)

# %%
imdb_df2.shape
# Out:
# (83, 15)

# %%
imdb_df_full = pd.concat([imdb_df1, imdb_df2], axis=0)

# %%
imdb_df_full.head()
# Out:
#                title     imdb_id                         title_link    year  \
# 0              Tenet   tt6723592   /title/tt6723592/?ref_=adv_li_tt  2020.0
# 1   The Midnight Sky  tt10539608  /title/tt10539608/?ref_=adv_li_tt  2020.0
# 2       Wonder Woman   tt0451279   /title/tt0451279/?ref_=adv_li_tt  2017.0
# 3  Avengers: Endgame   tt4154796   /title/tt4154796/?ref_=adv_li_tt  2019.0
# 4   Outside the Wire  tt10451914  /title/tt10451914/?ref_=adv_li_tt  2021.0
#
#    runtime mpaa_rating      director_name director_id  \
# 0    150.0       PG-13  Christopher Nolan   nm0634240
# 1    118.0       PG-13     George Clooney   nm0000123
# 2    141.0       PG-13      Patty Jenkins   nm0420941
# 3    181.0       PG-13               None        None
# 4    114.0           R    Mikael Håfström   nm0405632
#
#                        director_link genre_01   genre_02  genre_03  \
# 0  /name/nm0634240/?ref_=adv_li_dr_0   Action     Sci-Fi  Thriller
# 1  /name/nm0000123/?ref_=adv_li_dr_0    Drama    Fantasy    Sci-Fi
# 2  /name/nm0420941/?ref_=adv_li_dr_0   Action  Adventure   Fantasy
# 3                               None   Action  Adventure     Drama
# 4  /name/nm0405632/?ref_=adv_li_dr_0   Action  Adventure   Fantasy
#
#    imdb_rating     votes  metascore
# 0          7.5  268688.0       69.0
# 1          5.6   58011.0       58.0
# 2          7.4  564054.0       76.0
# 3          8.4  802218.0       78.0
# 4          5.4    9333.0       47.0

# %%
imdb_df_full.shape
# Out:
# (2083, 15)

# %%
mojo_df1 = pd.read_json('mojo_data.json', lines=True)
mojo_df2 = pd.read_json('mojo_data2.json', lines=True)

# %%
mojo_df1.shape, mojo_df2.shape
# Out:
# ((2000, 4), (83, 4))

# %%
mojo_df_full = pd.concat([mojo_df1, mojo_df2], axis =0)

# %%
mojo_df_full.shape
# Out:
# (2083, 4)

# %%
tomato_df1 = pd.read_json('tomato_data1.json', lines=True)
tomato_df2 = pd.read_json('tomato_data2.json', lines=True)

# %%
tomato_df1.shape, tomato_df2.shape
# Out:
# ((2000, 5), (2083, 5))

# %%
tomato_df_full = tomato_df2

# %%
imdb_df_full.head()
# Out:
#                title     imdb_id                         title_link    year  \
# 0              Tenet   tt6723592   /title/tt6723592/?ref_=adv_li_tt  2020.0
# 1   The Midnight Sky  tt10539608  /title/tt10539608/?ref_=adv_li_tt  2020.0
# 2       Wonder Woman   tt0451279   /title/tt0451279/?ref_=adv_li_tt  2017.0
# 3  Avengers: Endgame   tt4154796   /title/tt4154796/?ref_=adv_li_tt  2019.0
# 4   Outside the Wire  tt10451914  /title/tt10451914/?ref_=adv_li_tt  2021.0
#
#    runtime mpaa_rating      director_name director_id  \
# 0    150.0       PG-13  Christopher Nolan   nm0634240
# 1    118.0       PG-13     George Clooney   nm0000123
# 2    141.0       PG-13      Patty Jenkins   nm0420941
# 3    181.0       PG-13               None        None
# 4    114.0           R    Mikael Håfström   nm0405632
#
#                        director_link genre_01   genre_02  genre_03  \
# 0  /name/nm0634240/?ref_=adv_li_dr_0   Action     Sci-Fi  Thriller
# 1  /name/nm0000123/?ref_=adv_li_dr_0    Drama    Fantasy    Sci-Fi
# 2  /name/nm0420941/?ref_=adv_li_dr_0   Action  Adventure   Fantasy
# 3                               None   Action  Adventure     Drama
# 4  /name/nm0405632/?ref_=adv_li_dr_0   Action  Adventure   Fantasy
#
#    imdb_rating     votes  metascore
# 0          7.5  268688.0       69.0
# 1          5.6   58011.0       58.0
# 2          7.4  564054.0       76.0
# 3          8.4  802218.0       78.0
# 4          5.4    9333.0       47.0

# %%
tomato_df_full.head()
# Out:
#               title  tomatometer  tomato_ct  aud_score  \
# 0             tenet         70.0      324.0       76.0
# 1  the_midnight_sky         51.0      226.0       26.0
# 2      wonder_woman         83.0       12.0       78.0
# 3  avengers_endgame         94.0      532.0       90.0
# 4  outside_the_wire         36.0       58.0       33.0
#
#               aud_score_ct
# 0  Verified Ratings: 5,837
# 1                    2,122
# 2                    1,910
# 3                   70,830
# 4                      295

# %%
imdb_df_full['title_cc'] = imdb_df_full['title'].str.lower() 
imdb_df_full['title_cc'] = imdb_df_full['title_cc'].str.replace('&','and',regex=False)
imdb_df_full['title_cc'] = imdb_df_full['title_cc'].str.replace('\\','_',regex=True)
imdb_df_full['title_cc'] = imdb_df_full['title_cc'].str.replace('episode\s([ivx]*)\s-\s','',regex=True)
imdb_df_full['title_cc'] = imdb_df_full['title_cc'].str.replace("\s",'_',regex=True)
imdb_df_full['title_cc'] = imdb_df_full['title_cc'].str.replace('_+','_',regex=True)

# %%
imdb_df_full.head()
# Out:
#                title     imdb_id                         title_link    year  \
# 0              Tenet   tt6723592   /title/tt6723592/?ref_=adv_li_tt  2020.0
# 1   The Midnight Sky  tt10539608  /title/tt10539608/?ref_=adv_li_tt  2020.0
# 2       Wonder Woman   tt0451279   /title/tt0451279/?ref_=adv_li_tt  2017.0
# 3  Avengers: Endgame   tt4154796   /title/tt4154796/?ref_=adv_li_tt  2019.0
# 4   Outside the Wire  tt10451914  /title/tt10451914/?ref_=adv_li_tt  2021.0
#
#    runtime mpaa_rating      director_name director_id  \
# 0    150.0       PG-13  Christopher Nolan   nm0634240
# 1    118.0       PG-13     George Clooney   nm0000123
# 2    141.0       PG-13      Patty Jenkins   nm0420941
# 3    181.0       PG-13               None        None
# 4    114.0           R    Mikael Håfström   nm0405632
#
#                        director_link genre_01   genre_02  genre_03  \
# 0  /name/nm0634240/?ref_=adv_li_dr_0   Action     Sci-Fi  Thriller
# 1  /name/nm0000123/?ref_=adv_li_dr_0    Drama    Fantasy    Sci-Fi
# 2  /name/nm0420941/?ref_=adv_li_dr_0   Action  Adventure   Fantasy
# 3                               None   Action  Adventure     Drama
# 4  /name/nm0405632/?ref_=adv_li_dr_0   Action  Adventure   Fantasy
#
#    imdb_rating     votes  metascore           title_cc
# 0          7.5  268688.0       69.0              tenet
# 1          5.6   58011.0       58.0   the_midnight_sky
# 2          7.4  564054.0       76.0       wonder_woman
# 3          8.4  802218.0       78.0  avengers:_endgame
# 4          5.4    9333.0       47.0   outside_the_wire

# %%
mojo_df_full.head()
# Out:
#            id                         title_string     dom_gross  \
# 0   tt6723592              Tenet - Box Office Mojo   $57,929,000
# 1  tt10539608   The Midnight Sky - Box Office Mojo       $62,557
# 2   tt0451279       Wonder Woman - Box Office Mojo  $412,815,408
# 3   tt4154796  Avengers: Endgame - Box Office Mojo  $858,373,000
# 4  tt10451914   Outside the Wire - Box Office Mojo          None
#
#                                   release_date
# 0    August 26, 2020\n            (EMEA, APAC)
# 1  December 9, 2020\n            (South Korea)
# 2             May 30, 2017\n            (APAC)
# 3     April 24, 2019\n            (21 markets)
# 4                                         None

# %%
imdb_df_full.shape
# Out:
# (2083, 16)

# %%
tomato_df_full.shape
# Out:
# (2083, 5)

# %%
mojo_df_full.shape
# Out:
# (2083, 4)

# %%
imdb_df_full = imdb_df_full.sort_values(by='title_cc', ascending=True)

# %%
tomato_df_full = tomato_df_full.sort_values(by='title', ascending=True)

# %%
imdb_df_full = imdb_df_full.sort_values(by='imdb_id', ascending=True)

# %%
mojo_df_full = mojo_df_full.sort_values(by='id', ascending=True)

# %%
imdb_tomato = pd.merge(imdb_df_full, tomato_df_full, how='right', left_on='title_cc', right_on='title').fillna(np.nan)

# %%
imdb_tomato['title_cc'].value_counts()
# Out:
# fantastic_four            9
# frankenstein              9
# godzilla                  9
# the_lost_world            9
# cargo                     9
#                          ..
# the_door                  1
# trancers                  1
# flesh_for_frankenstein    1
# gandahar                  1
# the_cabbage_soup          1
# Name: title_cc, Length: 1613, dtype: int64

# %%
mojo_df_full.shape
# Out:
# (2083, 4)

# %%
imdb_df_full.shape
# Out:
# (2083, 16)

# %%
imdb_mojo = pd.merge(imdb_df_full, mojo_df_full, how='left', left_on='imdb_id', right_on='imdb_id').fillna(np.nan)

# %%
mojo_df_full.rename(columns = {'id':'imdb_id'}, inplace = True)

# %%
imdb_mojo.shape
# Out:
# (2093, 19)

# %%
imdb_mojo.head()
# Out:
#                title    imdb_id                        title_link    year  \
# 0     The Lost World  tt0016039  /title/tt0016039/?ref_=adv_li_tt  1925.0
# 1         Metropolis  tt0017136  /title/tt0017136/?ref_=adv_li_tt  1927.0
# 2  Woman in the Moon  tt0019901  /title/tt0019901/?ref_=adv_li_tt  1929.0
# 3       Frankenstein  tt0021884  /title/tt0021884/?ref_=adv_li_tt  1931.0
# 4           Svengali  tt0022454  /title/tt0022454/?ref_=adv_li_tt  1931.0
#
#    runtime mpaa_rating  director_name director_id  \
# 0    110.0      Passed  Harry O. Hoyt   nm0398464
# 1    153.0   Not Rated     Fritz Lang   nm0000485
# 2     95.0   Not Rated     Fritz Lang   nm0000485
# 3     70.0      Passed    James Whale   nm0001843
# 4     81.0    Approved    Archie Mayo   nm0562845
#
#                        director_link   genre_01 genre_02 genre_03  \
# 0  /name/nm0398464/?ref_=adv_li_dr_0  Adventure  Fantasy   Sci-Fi
# 1  /name/nm0000485/?ref_=adv_li_dr_0      Drama   Sci-Fi      NaN
# 2  /name/nm0000485/?ref_=adv_li_dr_0  Adventure   Comedy    Drama
# 3  /name/nm0001843/?ref_=adv_li_dr_0      Drama   Horror   Sci-Fi
# 4  /name/nm0562845/?ref_=adv_li_dr_0      Drama   Horror  Romance
#
#    imdb_rating     votes  metascore           title_cc  \
# 0          7.0    4624.0        NaN     the_lost_world
# 1          8.3  159589.0       98.0         metropolis
# 2          7.3    3028.0        NaN  woman_in_the_moon
# 3          7.8   65146.0       91.0       frankenstein
# 4          6.8    1793.0        NaN           svengali
#
#                           title_string   dom_gross  \
# 0     The Lost World - Box Office Mojo         NaN
# 1         Metropolis - Box Office Mojo  $1,236,166
# 2  Woman in the Moon - Box Office Mojo         NaN
# 3       Frankenstein - Box Office Mojo      $1,626
# 4           Svengali - Box Office Mojo         NaN
#
#                                 release_date
# 0                                        NaN
# 1        May 6, 1927\n            (Domestic)
# 2                                        NaN
# 3  November 21, 1931\n            (Domestic)
# 4                                        NaN

# %%
pd.set_option('display.max_rows', 75)

# %%
imdb_mojo['imdb_id'].value_counts()[0:25]
# Out:
# tt9264728    1
# tt1483013    1
# tt1355630    1
# tt5862242    1
# tt0074559    1
# tt1098327    1
# tt0080391    1
# tt8633542    1
# tt0081182    1
# tt2924392    1
# tt2580382    1
# tt0097100    1
# tt6544220    1
# tt0109836    1
# tt3289728    1
# tt0441796    1
# tt1139592    1
# tt0102975    1
# tt0775552    1
# tt6644200    1
# tt0067065    1
# tt2051879    1
# tt0016039    1
# tt6604188    1
# tt1023500    1
# Name: imdb_id, dtype: int64

# %%
imdb_mojo[imdb_mojo['id'].isin(['tt0102687', 'tt3864024', 'tt0455326', 'tt4397342','tt4720596'])]
# Out:
#                                                   title    imdb_id  \
# 515                                              Poison  tt0102687
# 516                                              Poison  tt0102687
# 517                                              Poison  tt0102687
# 518                                              Poison  tt0102687
# 949   Aqua Teen Hunger Force Colon Movie Film for Th...  tt0455326
# 950   Aqua Teen Hunger Force Colon Movie Film for Th...  tt0455326
# 951   Aqua Teen Hunger Force Colon Movie Film for Th...  tt0455326
# 952   Aqua Teen Hunger Force Colon Movie Film for Th...  tt0455326
# 1640                                         Lazer Team  tt3864024
# 1641                                         Lazer Team  tt3864024
# 1642                                         Lazer Team  tt3864024
# 1643                                         Lazer Team  tt3864024
# 1691                              Cities of Last Things  tt4397342
# 1692                              Cities of Last Things  tt4397342
# 1693                              Cities of Last Things  tt4397342
# 1694                              Cities of Last Things  tt4397342
# 1732                                          Curvature  tt4720596
# 1733                                          Curvature  tt4720596
# 1734                                          Curvature  tt4720596
# 1735                                          Curvature  tt4720596
#
#                             title_link    year  runtime mpaa_rating  \
# 515   /title/tt0102687/?ref_=adv_li_tt  1991.0     85.0           R
# 516   /title/tt0102687/?ref_=adv_li_tt  1991.0     85.0           R
# 517   /title/tt0102687/?ref_=adv_li_tt  1991.0     85.0           R
# 518   /title/tt0102687/?ref_=adv_li_tt  1991.0     85.0           R
# 949   /title/tt0455326/?ref_=adv_li_tt  2007.0     86.0           R
# 950   /title/tt0455326/?ref_=adv_li_tt  2007.0     86.0           R
# 951   /title/tt0455326/?ref_=adv_li_tt  2007.0     86.0           R
# 952   /title/tt0455326/?ref_=adv_li_tt  2007.0     86.0           R
# 1640  /title/tt3864024/?ref_=adv_li_tt  2015.0    102.0       PG-13
# 1641  /title/tt3864024/?ref_=adv_li_tt  2015.0    102.0       PG-13
# 1642  /title/tt3864024/?ref_=adv_li_tt  2015.0    102.0       PG-13
# 1643  /title/tt3864024/?ref_=adv_li_tt  2015.0    102.0       PG-13
# 1691  /title/tt4397342/?ref_=adv_li_tt  2018.0    106.0       TV-MA
# 1692  /title/tt4397342/?ref_=adv_li_tt  2018.0    106.0       TV-MA
# 1693  /title/tt4397342/?ref_=adv_li_tt  2018.0    106.0       TV-MA
# 1694  /title/tt4397342/?ref_=adv_li_tt  2018.0    106.0       TV-MA
# 1732  /title/tt4720596/?ref_=adv_li_tt  2017.0     90.0         NaN
# 1733  /title/tt4720596/?ref_=adv_li_tt  2017.0     90.0         NaN
# 1734  /title/tt4720596/?ref_=adv_li_tt  2017.0     90.0         NaN
# 1735  /title/tt4720596/?ref_=adv_li_tt  2017.0     90.0         NaN
#
#        director_name director_id                      director_link  \
# 515      Todd Haynes   nm0001331  /name/nm0001331/?ref_=adv_li_dr_0
# 516      Todd Haynes   nm0001331  /name/nm0001331/?ref_=adv_li_dr_0
# 517      Todd Haynes   nm0001331  /name/nm0001331/?ref_=adv_li_dr_0
# 518      Todd Haynes   nm0001331  /name/nm0001331/?ref_=adv_li_dr_0
# 949              NaN         NaN                                NaN
# 950              NaN         NaN                                NaN
# 951              NaN         NaN                                NaN
# 952              NaN         NaN                                NaN
# 1640     Matt Hullum   nm0401502  /name/nm0401502/?ref_=adv_li_dr_0
# 1641     Matt Hullum   nm0401502  /name/nm0401502/?ref_=adv_li_dr_0
# 1642     Matt Hullum   nm0401502  /name/nm0401502/?ref_=adv_li_dr_0
# 1643     Matt Hullum   nm0401502  /name/nm0401502/?ref_=adv_li_dr_0
# 1691      Wi Ding Ho   nm0387399  /name/nm0387399/?ref_=adv_li_dr_0
# 1692      Wi Ding Ho   nm0387399  /name/nm0387399/?ref_=adv_li_dr_0
# 1693      Wi Ding Ho   nm0387399  /name/nm0387399/?ref_=adv_li_dr_0
# 1694      Wi Ding Ho   nm0387399  /name/nm0387399/?ref_=adv_li_dr_0
# 1732  Diego Hallivis   nm3611504  /name/nm3611504/?ref_=adv_li_dr_0
# 1733  Diego Hallivis   nm3611504  /name/nm3611504/?ref_=adv_li_dr_0
# 1734  Diego Hallivis   nm3611504  /name/nm3611504/?ref_=adv_li_dr_0
# 1735  Diego Hallivis   nm3611504  /name/nm3611504/?ref_=adv_li_dr_0
#
#        genre_01 genre_02   genre_03  imdb_rating    votes  metascore  \
# 515       Drama   Horror    Romance          6.5   3945.0       67.0
# 516       Drama   Horror    Romance          6.5   3945.0       67.0
# 517       Drama   Horror    Romance          6.5   3945.0       67.0
# 518       Drama   Horror    Romance          6.5   3945.0       67.0
# 949   Animation   Action  Adventure          6.7  13324.0       54.0
# 950   Animation   Action  Adventure          6.7  13323.0       54.0
# 951   Animation   Action  Adventure          6.7  13324.0       54.0
# 952   Animation   Action  Adventure          6.7  13323.0       54.0
# 1640     Action   Comedy     Sci-Fi          5.6   9128.0       42.0
# 1641     Action   Comedy     Sci-Fi          5.6   9127.0       42.0
# 1642     Action   Comedy     Sci-Fi          5.6   9128.0       42.0
# 1643     Action   Comedy     Sci-Fi          5.6   9127.0       42.0
# 1691      Crime    Drama     Sci-Fi          6.2   1227.0       66.0
# 1692      Crime    Drama     Sci-Fi          6.2   1227.0       66.0
# 1693      Crime    Drama     Sci-Fi          6.2   1227.0       66.0
# 1694      Crime    Drama     Sci-Fi          6.2   1227.0       66.0
# 1732    Mystery   Sci-Fi   Thriller          4.8   1736.0       38.0
# 1733    Mystery   Sci-Fi   Thriller          4.8   1736.0       38.0
# 1734    Mystery   Sci-Fi   Thriller          4.8   1736.0       38.0
# 1735    Mystery   Sci-Fi   Thriller          4.8   1736.0       38.0
#
#                                                title_cc         id  \
# 515                                              poison  tt0102687
# 516                                              poison  tt0102687
# 517                                              poison  tt0102687
# 518                                              poison  tt0102687
# 949   aqua_teen_hunger_force_colon_movie_film_for_th...  tt0455326
# 950   aqua_teen_hunger_force_colon_movie_film_for_th...  tt0455326
# 951   aqua_teen_hunger_force_colon_movie_film_for_th...  tt0455326
# 952   aqua_teen_hunger_force_colon_movie_film_for_th...  tt0455326
# 1640                                         lazer_team  tt3864024
# 1641                                         lazer_team  tt3864024
# 1642                                         lazer_team  tt3864024
# 1643                                         lazer_team  tt3864024
# 1691                              cities_of_last_things  tt4397342
# 1692                              cities_of_last_things  tt4397342
# 1693                              cities_of_last_things  tt4397342
# 1694                              cities_of_last_things  tt4397342
# 1732                                          curvature  tt4720596
# 1733                                          curvature  tt4720596
# 1734                                          curvature  tt4720596
# 1735                                          curvature  tt4720596
#
#                                            title_string   dom_gross  \
# 515                            Poison - Box Office Mojo    $787,280
# 516                            Poison - Box Office Mojo    $787,280
# 517                            Poison - Box Office Mojo    $787,280
# 518                            Poison - Box Office Mojo    $787,280
# 949   Aqua Teen Hunger Force Colon Movie Film for Th...  $5,520,368
# 950   Aqua Teen Hunger Force Colon Movie Film for Th...  $5,520,368
# 951   Aqua Teen Hunger Force Colon Movie Film for Th...  $5,520,368
# 952   Aqua Teen Hunger Force Colon Movie Film for Th...  $5,520,368
# 1640                       Lazer Team - Box Office Mojo  $1,186,426
# 1641                       Lazer Team - Box Office Mojo  $1,186,426
# 1642                       Lazer Team - Box Office Mojo  $1,186,426
# 1643                       Lazer Team - Box Office Mojo  $1,186,426
# 1691            Cities of Last Things - Box Office Mojo         NaN
# 1692            Cities of Last Things - Box Office Mojo         NaN
# 1693            Cities of Last Things - Box Office Mojo         NaN
# 1694            Cities of Last Things - Box Office Mojo         NaN
# 1732                        Curvature - Box Office Mojo         NaN
# 1733                        Curvature - Box Office Mojo         NaN
# 1734                        Curvature - Box Office Mojo         NaN
# 1735                        Curvature - Box Office Mojo         NaN
#
#                                    release_date
# 515       April 5, 1991\n            (Domestic)
# 516       April 5, 1991\n            (Domestic)
# 517       April 5, 1991\n            (Domestic)
# 518       April 5, 1991\n            (Domestic)
# 949      April 13, 2007\n            (Domestic)
# 950      April 13, 2007\n            (Domestic)
# 951      April 13, 2007\n            (Domestic)
# 952      April 13, 2007\n            (Domestic)
# 1640   January 27, 2016\n            (Domestic)
# 1641   January 27, 2016\n            (Domestic)
# 1642   January 27, 2016\n            (Domestic)
# 1643   January 27, 2016\n            (Domestic)
# 1691                                        NaN
# 1692                                        NaN
# 1693                                        NaN
# 1694                                        NaN
# 1732  February 23, 2018\n            (Domestic)
# 1733  February 23, 2018\n            (Domestic)
# 1734  February 23, 2018\n            (Domestic)
# 1735  February 23, 2018\n            (Domestic)

# %%
imdb_mojo = imdb_mojo.drop([516,517,518,950, 951,952, 1641,1642,1643,1694,1692,1693, 1733,1734,1735])

# %%
imdb_mojo[imdb_mojo['imdb_id'].isin(['tt0102687', 'tt3864024', 'tt0455326', 'tt4397342','tt4720596'])]
# Out:
#                                                   title    imdb_id  \
# 515                                              Poison  tt0102687
# 949   Aqua Teen Hunger Force Colon Movie Film for Th...  tt0455326
# 1640                                         Lazer Team  tt3864024
# 1691                              Cities of Last Things  tt4397342
# 1732                                          Curvature  tt4720596
#
#                             title_link    year  runtime mpaa_rating  \
# 515   /title/tt0102687/?ref_=adv_li_tt  1991.0     85.0           R
# 949   /title/tt0455326/?ref_=adv_li_tt  2007.0     86.0           R
# 1640  /title/tt3864024/?ref_=adv_li_tt  2015.0    102.0       PG-13
# 1691  /title/tt4397342/?ref_=adv_li_tt  2018.0    106.0       TV-MA
# 1732  /title/tt4720596/?ref_=adv_li_tt  2017.0     90.0         NaN
#
#        director_name director_id                      director_link  \
# 515      Todd Haynes   nm0001331  /name/nm0001331/?ref_=adv_li_dr_0
# 949              NaN         NaN                                NaN
# 1640     Matt Hullum   nm0401502  /name/nm0401502/?ref_=adv_li_dr_0
# 1691      Wi Ding Ho   nm0387399  /name/nm0387399/?ref_=adv_li_dr_0
# 1732  Diego Hallivis   nm3611504  /name/nm3611504/?ref_=adv_li_dr_0
#
#        genre_01 genre_02   genre_03  imdb_rating    votes  metascore  \
# 515       Drama   Horror    Romance          6.5   3945.0       67.0
# 949   Animation   Action  Adventure          6.7  13324.0       54.0
# 1640     Action   Comedy     Sci-Fi          5.6   9128.0       42.0
# 1691      Crime    Drama     Sci-Fi          6.2   1227.0       66.0
# 1732    Mystery   Sci-Fi   Thriller          4.8   1736.0       38.0
#
#                                                title_cc  \
# 515                                              poison
# 949   aqua_teen_hunger_force_colon_movie_film_for_th...
# 1640                                         lazer_team
# 1691                              cities_of_last_things
# 1732                                          curvature
#
#                                            title_string   dom_gross  \
# 515                            Poison - Box Office Mojo    $787,280
# 949   Aqua Teen Hunger Force Colon Movie Film for Th...  $5,520,368
# 1640                       Lazer Team - Box Office Mojo  $1,186,426
# 1691            Cities of Last Things - Box Office Mojo         NaN
# 1732                        Curvature - Box Office Mojo         NaN
#
#                                    release_date
# 515       April 5, 1991\n            (Domestic)
# 949      April 13, 2007\n            (Domestic)
# 1640   January 27, 2016\n            (Domestic)
# 1691                                        NaN
# 1732  February 23, 2018\n            (Domestic)

# %%
imdb_mojo.shape
# Out:
# (2078, 19)

# %%
tomato_df_full.shape
# Out:
# (2083, 5)

# %%
tomato_df_full.head()
# Out:
#                        title  tomatometer  tomato_ct  aud_score aud_score_ct
# 1621                       1          NaN        NaN        NaN         None
# 1598  100_degrees_below_zero          8.0        NaN        NaN          114
# 1194          100_earthquake         14.0        NaN        NaN          106
# 265      10_cloverfield_lane         90.0      312.0       79.0       60,968
# 60                12_monkeys         89.0       70.0       88.0      391,142

# %%
imdb_mojo_tomato = pd.merge(imdb_mojo, tomato_df_full, how='left', left_on='title_cc', right_on='title').fillna(np.nan)

# %%
imdb_mojo_tomato.shape
# Out:
# (2208, 24)

# %%
title_counts = imdb_mojo_tomato['title_cc'].value_counts()

# %%
type(title_counts)
# Out:
# pandas.core.series.Series

# %%
title_counts.head()
# Out:
# fantastic_four    9
# godzilla          9
# frankenstein      9
# the_lost_world    9
# cargo             9
# Name: title_cc, dtype: int64

# %%
title_counts = title_counts[title_counts > 1].reset_index()

# %%
title_counts.head()
# Out:
#             index  title_cc
# 0  fantastic_four         9
# 1        godzilla         9
# 2    frankenstein         9
# 3  the_lost_world         9
# 4           cargo         9

# %%
title_counts.index
# Out:
# RangeIndex(start=0, stop=60, step=1)

# %%
imdb_mojo_tomato[imdb_mojo_tomato['title_cc'].isin(title_counts['index'])]
# Out:
#              title_x    imdb_id                        title_link    year  \
# 0     The Lost World  tt0016039  /title/tt0016039/?ref_=adv_li_tt  1925.0
# 1     The Lost World  tt0016039  /title/tt0016039/?ref_=adv_li_tt  1925.0
# 2     The Lost World  tt0016039  /title/tt0016039/?ref_=adv_li_tt  1925.0
# 3         Metropolis  tt0017136  /title/tt0017136/?ref_=adv_li_tt  1927.0
# 4         Metropolis  tt0017136  /title/tt0017136/?ref_=adv_li_tt  1927.0
# ...              ...        ...                               ...     ...
# 2106        Invasion  tt8060328  /title/tt8060328/?ref_=adv_li_tt  2020.0
# 2107        Invasion  tt8060328  /title/tt8060328/?ref_=adv_li_tt  2020.0
# 2157           Cargo  tt8992946  /title/tt8992946/?ref_=adv_li_tt  2019.0
# 2158           Cargo  tt8992946  /title/tt8992946/?ref_=adv_li_tt  2019.0
# 2159           Cargo  tt8992946  /title/tt8992946/?ref_=adv_li_tt  2019.0
#
#       runtime mpaa_rating     director_name director_id  \
# 0       110.0      Passed     Harry O. Hoyt   nm0398464
# 1       110.0      Passed     Harry O. Hoyt   nm0398464
# 2       110.0      Passed     Harry O. Hoyt   nm0398464
# 3       153.0   Not Rated        Fritz Lang   nm0000485
# 4       153.0   Not Rated        Fritz Lang   nm0000485
# ...       ...         ...               ...         ...
# 2106    134.0   Not Rated  Fedor Bondarchuk   nm0094080
# 2107    134.0   Not Rated  Fedor Bondarchuk   nm0094080
# 2157    119.0         NaN       Arati Kadav   nm6814179
# 2158    119.0         NaN       Arati Kadav   nm6814179
# 2159    119.0         NaN       Arati Kadav   nm6814179
#
#                           director_link   genre_01  ... metascore  \
# 0     /name/nm0398464/?ref_=adv_li_dr_0  Adventure  ...       NaN
# 1     /name/nm0398464/?ref_=adv_li_dr_0  Adventure  ...       NaN
# 2     /name/nm0398464/?ref_=adv_li_dr_0  Adventure  ...       NaN
# 3     /name/nm0000485/?ref_=adv_li_dr_0      Drama  ...      98.0
# 4     /name/nm0000485/?ref_=adv_li_dr_0      Drama  ...      98.0
# ...                                 ...        ...  ...       ...
# 2106  /name/nm0094080/?ref_=adv_li_dr_0     Action  ...       NaN
# 2107  /name/nm0094080/?ref_=adv_li_dr_0     Action  ...       NaN
# 2157  /name/nm6814179/?ref_=adv_li_dr_0      Drama  ...       NaN
# 2158  /name/nm6814179/?ref_=adv_li_dr_0      Drama  ...       NaN
# 2159  /name/nm6814179/?ref_=adv_li_dr_0      Drama  ...       NaN
#
#             title_cc                      title_string    dom_gross  \
# 0     the_lost_world  The Lost World - Box Office Mojo          NaN
# 1     the_lost_world  The Lost World - Box Office Mojo          NaN
# 2     the_lost_world  The Lost World - Box Office Mojo          NaN
# 3         metropolis      Metropolis - Box Office Mojo   $1,236,166
# 4         metropolis      Metropolis - Box Office Mojo   $1,236,166
# ...              ...                               ...          ...
# 2106        invasion        Invasion - Box Office Mojo  $16,262,755
# 2107        invasion        Invasion - Box Office Mojo  $16,262,755
# 2157           cargo           Cargo - Box Office Mojo          NaN
# 2158           cargo           Cargo - Box Office Mojo          NaN
# 2159           cargo           Cargo - Box Office Mojo          NaN
#
#                                   release_date         title_y tomatometer  \
# 0                                          NaN  the_lost_world       100.0
# 1                                          NaN  the_lost_world       100.0
# 2                                          NaN  the_lost_world       100.0
# 3          May 6, 1927\n            (Domestic)      metropolis         NaN
# 4          May 6, 1927\n            (Domestic)      metropolis         NaN
# ...                                        ...             ...         ...
# 2106  November 29, 2019\n            (Germany)        invasion        19.0
# 2107  November 29, 2019\n            (Germany)        invasion        19.0
# 2157                                       NaN           cargo        19.0
# 2158                                       NaN           cargo        19.0
# 2159                                       NaN           cargo        19.0
#
#      tomato_ct aud_score aud_score_ct
# 0         15.0      69.0        3,249
# 1         15.0      69.0        3,249
# 2         15.0      69.0        3,249
# 3          NaN       NaN          NaN
# 4          NaN       NaN          NaN
# ...        ...       ...          ...
# 2106     164.0      40.0      236,143
# 2107     164.0      40.0      236,143
# 2157       NaN       NaN        1,070
# 2158       NaN       NaN        1,070
# 2159       NaN       NaN        1,070
#
# [249 rows x 24 columns]

# %%
imdb_mojo_tomato.drop_duplicates()
# Out:
#                                title_x    imdb_id  \
# 0                       The Lost World  tt0016039
# 3                           Metropolis  tt0017136
# 5                    Woman in the Moon  tt0019901
# 6                         Frankenstein  tt0021884
# 9                             Svengali  tt0022454
# ...                                ...        ...
# 2203                            Breach  tt9820556
# 2204           The Banana Splits Movie  tt9831136
# 2205                     Escape Room 2  tt9844522
# 2206  Untitled: The Walking Dead Movie  tt9859436
# 2207                They Cloned Tyrone  tt9873892
#
#                             title_link    year  runtime mpaa_rating  \
# 0     /title/tt0016039/?ref_=adv_li_tt  1925.0    110.0      Passed
# 3     /title/tt0017136/?ref_=adv_li_tt  1927.0    153.0   Not Rated
# 5     /title/tt0019901/?ref_=adv_li_tt  1929.0     95.0   Not Rated
# 6     /title/tt0021884/?ref_=adv_li_tt  1931.0     70.0      Passed
# 9     /title/tt0022454/?ref_=adv_li_tt  1931.0     81.0    Approved
# ...                                ...     ...      ...         ...
# 2203  /title/tt9820556/?ref_=adv_li_tt  2020.0     92.0           R
# 2204  /title/tt9831136/?ref_=adv_li_tt  2019.0     89.0           R
# 2205  /title/tt9844522/?ref_=adv_li_tt  2021.0      NaN         NaN
# 2206  /title/tt9859436/?ref_=adv_li_tt     NaN      NaN         NaN
# 2207  /title/tt9873892/?ref_=adv_li_tt     NaN      NaN         NaN
#
#            director_name director_id                      director_link  \
# 0          Harry O. Hoyt   nm0398464  /name/nm0398464/?ref_=adv_li_dr_0
# 3             Fritz Lang   nm0000485  /name/nm0000485/?ref_=adv_li_dr_0
# 5             Fritz Lang   nm0000485  /name/nm0000485/?ref_=adv_li_dr_0
# 6            James Whale   nm0001843  /name/nm0001843/?ref_=adv_li_dr_0
# 9            Archie Mayo   nm0562845  /name/nm0562845/?ref_=adv_li_dr_0
# ...                  ...         ...                                ...
# 2203          John Suits   nm2986811  /name/nm2986811/?ref_=adv_li_dr_0
# 2204  Danishka Esterhazy   nm0261629  /name/nm0261629/?ref_=adv_li_dr_0
# 2205        Adam Robitel   nm0733263  /name/nm0733263/?ref_=adv_li_dr_0
# 2206       Greg Nicotero   nm0630524  /name/nm0630524/?ref_=adv_li_dr_0
# 2207         Juel Taylor   nm3541432  /name/nm3541432/?ref_=adv_li_dr_0
#
#        genre_01  ... metascore                          title_cc  \
# 0     Adventure  ...       NaN                    the_lost_world
# 3         Drama  ...      98.0                        metropolis
# 5     Adventure  ...       NaN                 woman_in_the_moon
# 6         Drama  ...      91.0                      frankenstein
# 9         Drama  ...       NaN                          svengali
# ...         ...  ...       ...                               ...
# 2203     Action  ...       NaN                            breach
# 2204     Comedy  ...       NaN           the_banana_splits_movie
# 2205     Action  ...       NaN                     escape_room_2
# 2206      Drama  ...       NaN  untitled:_the_walking_dead_movie
# 2207     Comedy  ...       NaN                they_cloned_tyrone
#
#                                            title_string   dom_gross  \
# 0                      The Lost World - Box Office Mojo         NaN
# 3                          Metropolis - Box Office Mojo  $1,236,166
# 5                   Woman in the Moon - Box Office Mojo         NaN
# 6                        Frankenstein - Box Office Mojo      $1,626
# 9                            Svengali - Box Office Mojo         NaN
# ...                                                 ...         ...
# 2203                           Breach - Box Office Mojo     $36,721
# 2204          The Banana Splits Movie - Box Office Mojo         NaN
# 2205                    Escape Room 2 - Box Office Mojo         NaN
# 2206  Untitled: The Walking Dead Movie - Box Office ...         NaN
# 2207               They Cloned Tyrone - Box Office Mojo         NaN
#
#                                      release_date                  title_y  \
# 0                                             NaN           the_lost_world
# 3             May 6, 1927\n            (Domestic)               metropolis
# 5                                             NaN        woman_in_the_moon
# 6       November 21, 1931\n            (Domestic)             frankenstein
# 9                                             NaN                 svengali
# ...                                           ...                      ...
# 2203  December 17, 2020\n            (Russia/CIS)                   breach
# 2204                                          NaN  the_banana_splits_movie
# 2205                                          NaN            escape_room_2
# 2206                                          NaN                      NaN
# 2207                                          NaN       they_cloned_tyrone
#
#      tomatometer tomato_ct aud_score aud_score_ct
# 0          100.0      15.0      69.0        3,249
# 3            NaN       NaN       NaN          NaN
# 5           75.0       8.0      72.0          643
# 6            0.0       NaN       NaN          113
# 9            NaN       NaN       NaN          NaN
# ...          ...       ...       ...          ...
# 2203        84.0     177.0      67.0      377,372
# 2204        63.0      19.0      50.0          183
# 2205         NaN       NaN       NaN          NaN
# 2206         NaN       NaN       NaN          NaN
# 2207         NaN       NaN       NaN          NaN
#
# [2080 rows x 24 columns]

# %%
imdb_mojo_tomato = imdb_mojo_tomato.drop_duplicates()

# %%
imdb_mojo_tomato.drop('title_y', axis=1)
# Out:
#                                title_x    imdb_id  \
# 0                       The Lost World  tt0016039
# 3                           Metropolis  tt0017136
# 5                    Woman in the Moon  tt0019901
# 6                         Frankenstein  tt0021884
# 9                             Svengali  tt0022454
# ...                                ...        ...
# 2203                            Breach  tt9820556
# 2204           The Banana Splits Movie  tt9831136
# 2205                     Escape Room 2  tt9844522
# 2206  Untitled: The Walking Dead Movie  tt9859436
# 2207                They Cloned Tyrone  tt9873892
#
#                             title_link    year  runtime mpaa_rating  \
# 0     /title/tt0016039/?ref_=adv_li_tt  1925.0    110.0      Passed
# 3     /title/tt0017136/?ref_=adv_li_tt  1927.0    153.0   Not Rated
# 5     /title/tt0019901/?ref_=adv_li_tt  1929.0     95.0   Not Rated
# 6     /title/tt0021884/?ref_=adv_li_tt  1931.0     70.0      Passed
# 9     /title/tt0022454/?ref_=adv_li_tt  1931.0     81.0    Approved
# ...                                ...     ...      ...         ...
# 2203  /title/tt9820556/?ref_=adv_li_tt  2020.0     92.0           R
# 2204  /title/tt9831136/?ref_=adv_li_tt  2019.0     89.0           R
# 2205  /title/tt9844522/?ref_=adv_li_tt  2021.0      NaN         NaN
# 2206  /title/tt9859436/?ref_=adv_li_tt     NaN      NaN         NaN
# 2207  /title/tt9873892/?ref_=adv_li_tt     NaN      NaN         NaN
#
#            director_name director_id                      director_link  \
# 0          Harry O. Hoyt   nm0398464  /name/nm0398464/?ref_=adv_li_dr_0
# 3             Fritz Lang   nm0000485  /name/nm0000485/?ref_=adv_li_dr_0
# 5             Fritz Lang   nm0000485  /name/nm0000485/?ref_=adv_li_dr_0
# 6            James Whale   nm0001843  /name/nm0001843/?ref_=adv_li_dr_0
# 9            Archie Mayo   nm0562845  /name/nm0562845/?ref_=adv_li_dr_0
# ...                  ...         ...                                ...
# 2203          John Suits   nm2986811  /name/nm2986811/?ref_=adv_li_dr_0
# 2204  Danishka Esterhazy   nm0261629  /name/nm0261629/?ref_=adv_li_dr_0
# 2205        Adam Robitel   nm0733263  /name/nm0733263/?ref_=adv_li_dr_0
# 2206       Greg Nicotero   nm0630524  /name/nm0630524/?ref_=adv_li_dr_0
# 2207         Juel Taylor   nm3541432  /name/nm3541432/?ref_=adv_li_dr_0
#
#        genre_01  ...     votes metascore                          title_cc  \
# 0     Adventure  ...    4624.0       NaN                    the_lost_world
# 3         Drama  ...  159589.0      98.0                        metropolis
# 5     Adventure  ...    3028.0       NaN                 woman_in_the_moon
# 6         Drama  ...   65146.0      91.0                      frankenstein
# 9         Drama  ...    1793.0       NaN                          svengali
# ...         ...  ...       ...       ...                               ...
# 2203     Action  ...    4304.0       NaN                            breach
# 2204     Comedy  ...    2632.0       NaN           the_banana_splits_movie
# 2205     Action  ...       NaN       NaN                     escape_room_2
# 2206      Drama  ...       NaN       NaN  untitled:_the_walking_dead_movie
# 2207     Comedy  ...       NaN       NaN                they_cloned_tyrone
#
#                                            title_string   dom_gross  \
# 0                      The Lost World - Box Office Mojo         NaN
# 3                          Metropolis - Box Office Mojo  $1,236,166
# 5                   Woman in the Moon - Box Office Mojo         NaN
# 6                        Frankenstein - Box Office Mojo      $1,626
# 9                            Svengali - Box Office Mojo         NaN
# ...                                                 ...         ...
# 2203                           Breach - Box Office Mojo     $36,721
# 2204          The Banana Splits Movie - Box Office Mojo         NaN
# 2205                    Escape Room 2 - Box Office Mojo         NaN
# 2206  Untitled: The Walking Dead Movie - Box Office ...         NaN
# 2207               They Cloned Tyrone - Box Office Mojo         NaN
#
#                                      release_date tomatometer tomato_ct  \
# 0                                             NaN       100.0      15.0
# 3             May 6, 1927\n            (Domestic)         NaN       NaN
# 5                                             NaN        75.0       8.0
# 6       November 21, 1931\n            (Domestic)         0.0       NaN
# 9                                             NaN         NaN       NaN
# ...                                           ...         ...       ...
# 2203  December 17, 2020\n            (Russia/CIS)        84.0     177.0
# 2204                                          NaN        63.0      19.0
# 2205                                          NaN         NaN       NaN
# 2206                                          NaN         NaN       NaN
# 2207                                          NaN         NaN       NaN
#
#      aud_score  aud_score_ct
# 0         69.0         3,249
# 3          NaN           NaN
# 5         72.0           643
# 6          NaN           113
# 9          NaN           NaN
# ...        ...           ...
# 2203      67.0       377,372
# 2204      50.0           183
# 2205       NaN           NaN
# 2206       NaN           NaN
# 2207       NaN           NaN
#
# [2080 rows x 23 columns]

# %%
imdb_mojo_tomato.to_json('imdb_mojo_tomato.json', orient='records', lines=True)

# %%
budget_df_clean = pd.read_json('budget_df_cleaned.json', lines=True)

# %%
budget_df_clean.shape
# Out:
# (5049, 7)

# %%
imdb_mojo_tomato.shape
# Out:
# (2080, 24)

# %%
budget_df_clean = budget_df_clean.sort_values(by='title_cc', ascending=True)

# %%
imdb_mojo_tomato.columns
# Out:
# Index(['title_x', 'imdb_id', 'title_link', 'year', 'runtime', 'mpaa_rating',
#        'director_name', 'director_id', 'director_link', 'genre_01', 'genre_02',
#        'genre_03', 'imdb_rating', 'votes', 'metascore', 'title_cc',
#        'title_string', 'dom_gross', 'release_date', 'title_y', 'tomatometer',
#        'tomato_ct', 'aud_score', 'aud_score_ct'],
#       dtype='object')

# %%
budget_df_clean['title']
# Out:
# 418                    10,000 B.C.
# 584                 102 Dalmatians
# 3192           10 Cloverfield Lane
# 3652         10 Days in a Madhouse
# 3457    10 Things I Hate About You
#                    ...
# 220                       Zootopia
# 3161                          Zulu
# 2598                     Zwartboek
# 4458          Ãpouse-moi mon pote
# 2865            é·æ±ä¸è (CJ7)
# Name: title, Length: 5049, dtype: object

# %%
imdb_mojo_tomato = imdb_mojo_tomato.sort_values(by='title_cc', ascending=True)

# %%
ITMB = pd.merge(imdb_mojo_tomato, budget_df_clean, how='left', left_on='title_cc', right_on='title_cc').fillna(np.nan)

# %%
imdb_mojo_tomato['dom_gross'] = imdb_mojo_tomato['dom_gross'].str.strip('$')

# %%
imdb_mojo_tomato['dom_gross'] = imdb_mojo_tomato['dom_gross'].str.replace(',', '',regex=True)

# %%
imdb_mojo_tomato['dom_gross'] = imdb_mojo_tomato['dom_gross'].fillna('0')

# %%
imdb_mojo_tomato['dom_gross'] = imdb_mojo_tomato['dom_gross'].astype('int64')

# %%
imdb_mojo_tomato['dom_gross'] = imdb_mojo_tomato['dom_gross'].astype('str')

# %%
budget_df_clean['dom_gross']=budget_df_clean['dom_gross'].astype('str')

# %%
imdb_mojo_tomato['dom_gross'].describe()
# Out:
# count    2.080000e+03
# mean     3.017913e+07
# std      8.077319e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.462130e+05
# 75%      1.979536e+07
# max      9.366622e+08
# Name: dom_gross, dtype: float64

# %%
ITMB.shape
# Out:
# (2113, 30)

# %%
ITMB[['title_x', 'title_cc_x', 'title_cc_y']]
# Out:
#                         title_x               title_cc_x          title_cc_y
# 0       *batteries not included  *batteries_not_included                 NaN
# 1                            +1                       +1                1114
# 2                            +1                       +1                1612
# 3                            +1                       +1                1776
# 4                            +1                       +1                 213
# ...                         ...                      ...                 ...
# 241878                 Zoombies                 zoombies                zulu
# 241879                 Zoombies                 zoombies  ãpousemoi_mon_pote
# 241880                 Æon Flux                 æon_flux                 NaN
# 241881                Évolution                évolution                 NaN
# 241882                 Órbita 9                 órbita_9                 NaN
#
# [241883 rows x 3 columns]

# %%
ITMB_minimal = ITMB[(ITMB['dom_gross_x'].notna()) & (ITMB['dom_gross_y'].notna())]

# %%
tomato_titles = []
budget_titles = []

# %%
ITMB_minimal.shape
# Out:
# (554, 30)

# %%
imdb_mojo_tomato.shape
# Out:
# (2080, 24)

# %%
budget_df_clean.shape
# Out:
# (5049, 7)

# %%
ITMB_minimal.columns
# Out:
# Index(['title_x', 'imdb_id', 'title_link', 'year', 'runtime', 'mpaa_rating',
#        'director_name', 'director_id', 'director_link', 'genre_01', 'genre_02',
#        'genre_03', 'imdb_rating', 'votes', 'metascore', 'title_cc',
#        'title_string', 'dom_gross_x', 'release_date_x', 'title_y',
#        'tomatometer', 'tomato_ct', 'aud_score', 'aud_score_ct', 'title',
#        'release_date_y', 'budget', 'dom_gross_y', 'ww_gross', 'release_date2'],
#       dtype='object')

# %%
ITMB_minimal.to_json('ITMB_data.json', orient='records', lines=True)

# %%
tomato_str = imdb_mojo_tomato['title_cc'].str[0:4]

# %%
tomato_gross = imdb_mojo_tomato['dom_gross'].str[0:4]

# %%
budget_str = budget_df_clean['title_cc'][0:4]

# %%
budget_gross = budget_df_clean['dom_gross'].str[0:4]

# %%
ITMB.shape
# Out:
# (2080, 34)

# %%
ITMB.head()
# Out:
#    best_match_score __id_left __id_right                  title_x    imdb_id  \
# 0               NaN    0_left       None  *batteries not included  tt0092494
# 1               NaN    1_left       None                       +1  tt2395385
# 2               NaN    2_left       None          10.0 Earthquake  tt3488056
# 3               NaN    3_left       None   100 Degrees Below Zero  tt2538128
# 4          0.252118    4_left    2_right      10 Cloverfield Lane  tt1179933
#
#                          title_link    year  runtime mpaa_rating  \
# 0  /title/tt0092494/?ref_=adv_li_tt  1987.0    106.0          PG
# 1  /title/tt2395385/?ref_=adv_li_tt  2013.0     96.0   Not Rated
# 2  /title/tt3488056/?ref_=adv_li_tt  2014.0     88.0          PG
# 3  /title/tt2538128/?ref_=adv_li_tt  2013.0     89.0   Not Rated
# 4  /title/tt1179933/?ref_=adv_li_tt  2016.0    103.0       PG-13
#
#       director_name  ... tomato_ct aud_score aud_score_ct  \
# 0   Matthew Robbins  ...       NaN       NaN          NaN
# 1    Dennis Iliadis  ...       NaN       NaN          NaN
# 2      David Gidali  ...       NaN       NaN          NaN
# 3   R.D. Braunstein  ...       NaN       NaN          114
# 4  Dan Trachtenberg  ...     312.0      79.0       60,968
#
#                  title release_date_right      budget  dom_gross_right  \
# 0                  NaN                NaN         NaN              NaN
# 1                  NaN                NaN         NaN              NaN
# 2                  NaN                NaN         NaN              NaN
# 3                  NaN                NaN         NaN              NaN
# 4  10 Cloverfield Lane       1.451866e+12  15000000.0         72082999
#
#      ww_gross       title_cc_right release_date2
# 0         NaN                  NaN           NaN
# 1         NaN                  NaN           NaN
# 2         NaN                  NaN           NaN
# 3         NaN                  NaN           NaN
# 4  72082999.0  10_cloverfield_lane   Jan 4, 2016
#
# [5 rows x 34 columns]

# %%
ITMB.columns
# Out:
# Index(['title_x', 'imdb_id', 'title_link', 'year', 'runtime', 'mpaa_rating',
#        'director_name', 'director_id', 'director_link', 'genre_01', 'genre_02',
#        'genre_03', 'imdb_rating', 'votes', 'metascore', 'title_cc',
#        'title_string', 'dom_gross_x', 'release_date_x', 'title_y',
#        'tomatometer', 'tomato_ct', 'aud_score', 'aud_score_ct', 'title',
#        'release_date_y', 'budget', 'dom_gross_y', 'ww_gross', 'release_date2'],
#       dtype='object')
